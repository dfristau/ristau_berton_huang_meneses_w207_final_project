# %% [markdown]
# # Test Set Evaluation of Top Performing Models
#
# ## Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt   
# %matplotlib inline
from music21 import *
from IPython.display import Audio
from intervaltree import Interval,IntervalTree
import pandas as pd
import seaborn as sns

from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
import sklearn.model_selection as model_selection
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import tensorflow as tf

from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Import csv features which were extracted from earlier Data PreProcessing notebook

# %%
X_train_w = pd.read_csv('../data/X_train_w.csv',index_col = 0)
X_train_m = pd.read_csv('../data/X_train_m.csv',index_col = 0)
X_train_c = pd.read_csv('../data/X_train_c.csv',index_col = 0)
X_test_w = pd.read_csv('../data/X_test_w.csv',index_col = 0)
X_test_m = pd.read_csv('../data/X_test_m.csv',index_col = 0)
X_test_c = pd.read_csv('../data/X_test_c.csv',index_col = 0)
y_train_w = pd.read_csv('../data/y_train_w.csv',index_col = 0)
y_train_m = pd.read_csv('../data/y_train_m.csv',index_col = 0)
y_train_c = pd.read_csv('../data/y_train_c.csv',index_col = 0)
y_test_w = pd.read_csv('../data/y_test_w.csv',index_col = 0)
y_test_m = pd.read_csv('../data/y_test_m.csv',index_col = 0)
y_test_c = pd.read_csv('../data/y_test_c.csv',index_col = 0)

# %% [markdown]
# ## Cross Validation Set Accuracy Results
# | Model               | Feature Set | Model Variant                                           | Highest CV Score | Mean CV Score |
# |---------------------|-------------|---------------------------------------------------------|------------------|---------------|
# | Logistic Regression | Spectral    | Baseline                                                | 94.23%           | 89.75%        |
# | Logistic Regression | Spectral    | PCA                                                     | 71.15%           | 68.83%        |
# | Logistic Regression | Midi        | Baseline                                                | 76.92%           | 71.10%        |
# | Logistic Regression | Midi        | PCA                                                     | 48.08%           | 41.49%        |
# | Logistic Regression | Combined    | Baseline                                                | 92.31%           | 85.56%        |
# | Logistic Regression | Combined    | PCA                                                     | 48.08%           | 45.64%        |
# | Naive Bayes         | Spectral    | Baseline                                                | 71.69%           | 68.41%        |
# | Naive Bayes         | Midi        | Baseline                                                | 75.00%           | 59.00%        |
# | Naive Bayes         | Combined    | Baseline                                                | 75.47%           | 73.00%        |
# | Decision Tree       | Spectral    | Baseline                                                | 80.77%           | 75.68%        |
# | Decision Tree       | Midi        | Baseline                                                | 86.79%           | 84.03%        |
# | Decision Tree       | Combined    | Baseline                                                | 94.23%           | 84.83%        |
# | Random Forest       | Spectral    | Baseline                                                | 86.54%           | 83.29%        |
# | Random Forest       | Spectral    | w/SMOTE                                                 | 100%             | 99.56%        |
# | Random Forest       | Spectral    | w/SMOTE +  Hyperparameter Tuning                        | ?                | ?             |
# | Random Forest       | Midi        | Baseline                                                | 94.34%           | 89.75%        |
# | Random Forest       | Midi        | w/SMOTE                                                 | 99.56%           | 99.34%        |
# | Random Forest       | Midi        | w/SMOTE + Hyperparameter Tuning                         | ?                | ?             |
# | Random Forest       | Combined    | Baseline                                                | 90.39%           | 86.72%        |
# | Random Forest       | Combined    | w/SMOTE                                                 | 100%             | 99.29%        |
# | Random Forest       | Combined    | w/SMOTE + Hyperparameter Tuning                         | ?                | ?             |
# | SVM                 | Spectral    | Baseline                                                | 67.39%           | 64.97%        |
# | SVM                 | Spectral    | w/Hyperparameter Tuning                                 | 95.65%           | 91.35%        |
# | SVM                 | Spectral    | w/Hyperparamater Tuning + PCA                           | 94.38%           | 90.47%        |
# | SVM                 | Spectral    | w/Hyperparameter Tuning + PCA + SMOTE                   | 100%             | 99.38%        |
# | SVM                 | Spectral    | w/Hyperparameter Tuning +  PCA + SMOTE + MinMaxScaler   | 77.33%           | 72.98%        |
# | SVM                 | Spectral    | w/Hyperparameter Tuning +  PCA + SMOTE + StandardScaler | 98.67%           | 97.24%        |
# | SVM                 | Midi        | Baseline                                                | 73.91%           | 73.17%        |
# | SVM                 | Midi        | w/Hyperparameter Tuning                                 | ?                | ?             |
# | SVM                 | Midi        | w/SMOTE                                                 | ?                | ?             |
# | SVM                 | Midi        | w/PCA                                                   | ?                | ?             |
# | SVM                 | Combined    | Baseline                                                | 73.91%           | 73.17%        |
# | SVM                 | Combined    | w/Hyperparameter Tuning                                 | ?                | ?             |
# | SVM                 | Combined    | w/SMOTE                                                 | ?                | ?             |
# | SVM                 | Combined    | w/PCA                                                   | ?                | ?             |
# | Neural Network      | Spectral    | Baseline (ADAM, 5 Hidden Layers)                        | 100%             | 100%          |
# | Neural Network      | Midi        | Baseline (ADAM, 5 Hidden Layers)                        | 84.85%           | 83.55%        |
# | Neural Network      | Combined    | Baseline (ADAM, 5 Hidden Layers)                        | 86.15%           | 81.82%        |

# %% [markdown]
# ## Top Performing Models
#
# | Model               | Feature Set | Model Variant                                            | Max CV Score | Mean CV Score |
# |---------------------|-------------|----------------------------------------------------------|--------------|---------------|
# | Neural Network      | Spectral    | Baseline (ADAM, 5 Hidden Layers)                         | 100%         | 100%          |
# | Random Forest       | Spectral    | w/SMOTE                                                  | 100%         | 99.56%        |
# | SVM                 | Spectral    | w/Hyperparameter   Tuning + PCA + SMOTE                  | 100%         | 99.38%        |
# | Random Forest       | Midi        | w/SMOTE                                                  | 99.56%       | 99.34%        |
# | Random Forest       | Combined    | w/SMOTE                                                  | 100%         | 99.29%        |
# | SVM                 | Spectral    | w/Hyperparameter   Tuning + PCA + SMOTE + StandardScaler | 98.67%       | 97.24%        |
# | SVM                 | Spectral    | w/Hyperparameter   Tuning                                | 95.65%       | 91.35%        |
# | SVM                 | Spectral    | w/Hyperparamater   Tuning + PCA                          | 94.38%       | 90.47%        |
# | Logistic Regression | Spectral    | Baseline                                                 | 94.23%       | 89.75%        |
# | Random Forest       | Midi        | Baseline                                                 | 94.34%       | 89.75%        |

# %% [markdown]
# ### Neural Network - Spectral - Baseline

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(176, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(90, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(70, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(21)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
history = model.fit(X_train_w, y_train_w, epochs=200)
predictions = model.predict(X_test_w)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Epoch 1/200
# 8/8 [==============================] - 1s 4ms/step - loss: 5.0032 - accuracy: 0.3333
# Epoch 2/200
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7950 - accuracy: 0.5152
# Epoch 3/200
# 8/8 [==============================] - 0s 5ms/step - loss: 1.3109 - accuracy: 0.6104
# Epoch 4/200
# 8/8 [==============================] - 0s 12ms/step - loss: 1.0787 - accuracy: 0.6364
# Epoch 5/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8014 - accuracy: 0.7662
# Epoch 6/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6730 - accuracy: 0.7965
# Epoch 7/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7845 - accuracy: 0.7792
# Epoch 8/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6179 - accuracy: 0.8398
# Epoch 9/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5584 - accuracy: 0.8442
# Epoch 10/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5389 - accuracy: 0.8225
# Epoch 11/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8874
# Epoch 12/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3899 - accuracy: 0.8658
# Epoch 13/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3432 - accuracy: 0.8918
# Epoch 14/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3539 - accuracy: 0.8788
# Epoch 15/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3626 - accuracy: 0.9004
# Epoch 16/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2666 - accuracy: 0.9091
# Epoch 17/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2787 - accuracy: 0.8874
# Epoch 18/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2614 - accuracy: 0.9134
# Epoch 19/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4033 - accuracy: 0.8831
# Epoch 20/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4934 - accuracy: 0.8528
# Epoch 21/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3079 - accuracy: 0.9091
# Epoch 22/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2873 - accuracy: 0.9177
# Epoch 23/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.9221
# Epoch 24/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2626 - accuracy: 0.9091
# Epoch 25/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3357 - accuracy: 0.9134
# Epoch 26/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3516 - accuracy: 0.8874
# Epoch 27/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2269 - accuracy: 0.9177
# Epoch 28/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2295 - accuracy: 0.9177
# Epoch 29/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1759 - accuracy: 0.9481
# Epoch 30/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.9307
# Epoch 31/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2626 - accuracy: 0.9221
# Epoch 32/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2933 - accuracy: 0.9134
# Epoch 33/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.9004
# Epoch 34/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2003 - accuracy: 0.9437
# Epoch 35/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1833 - accuracy: 0.9351
# Epoch 36/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1442 - accuracy: 0.9481
# Epoch 37/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9654
# Epoch 38/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1103 - accuracy: 0.9567
# Epoch 39/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0772 - accuracy: 0.9827
# Epoch 40/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0757 - accuracy: 0.9740
# Epoch 41/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.9740
# Epoch 42/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1125 - accuracy: 0.9697
# Epoch 43/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9697
# Epoch 44/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.9784
# Epoch 45/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1237 - accuracy: 0.9394
# Epoch 46/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3134 - accuracy: 0.9264
# Epoch 47/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2057 - accuracy: 0.9177
# Epoch 48/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1254 - accuracy: 0.9567
# Epoch 49/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2186 - accuracy: 0.9264
# Epoch 50/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.1333 - accuracy: 0.9481
# Epoch 51/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1384 - accuracy: 0.9567
# Epoch 52/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9567
# Epoch 53/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1080 - accuracy: 0.9697
# Epoch 54/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0805 - accuracy: 0.9740
# Epoch 55/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9870
# Epoch 56/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0636 - accuracy: 0.9784
# Epoch 57/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 0.9827
# Epoch 58/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0606 - accuracy: 0.9784
# Epoch 59/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9827
# Epoch 60/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0398 - accuracy: 0.9870
# Epoch 61/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0768 - accuracy: 0.9784
# Epoch 62/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 0.9610
# Epoch 63/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0286 - accuracy: 0.9957
# Epoch 64/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0337 - accuracy: 0.9913
# Epoch 65/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0232 - accuracy: 0.9957
# Epoch 66/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0612 - accuracy: 0.9697
# Epoch 67/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2477 - accuracy: 0.9437
# Epoch 68/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7032 - accuracy: 0.8398
# Epoch 69/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5533 - accuracy: 0.8268
# Epoch 70/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2140 - accuracy: 0.9351
# Epoch 71/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2168 - accuracy: 0.9351
# Epoch 72/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1726 - accuracy: 0.9481
# Epoch 73/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1012 - accuracy: 0.9827
# Epoch 74/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0492 - accuracy: 0.9913
# Epoch 75/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0509 - accuracy: 0.9870
# Epoch 76/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0312 - accuracy: 0.9913
# Epoch 77/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0264 - accuracy: 0.9957
# Epoch 78/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 79/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9957
# Epoch 80/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 81/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 82/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 83/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 84/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 85/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 86/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 87/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9957
# Epoch 88/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 89/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 90/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 91/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 92/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 93/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 95/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 96/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 97/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 98/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 99/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 100/200
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 101/200
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 102/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 103/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 106/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 107/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 108/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 109/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 110/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 112/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 113/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 114/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9482e-04 - accuracy: 1.0000
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7153e-04 - accuracy: 1.0000
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.9743e-04 - accuracy: 1.0000
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.8149e-04 - accuracy: 1.0000
# Epoch 121/200
# 8/8 [==============================] - 0s 3ms/step - loss: 7.4260e-04 - accuracy: 1.0000
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 7.1389e-04 - accuracy: 1.0000
# Epoch 123/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.9626e-04 - accuracy: 1.0000
# Epoch 124/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.7525e-04 - accuracy: 1.0000
# Epoch 125/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5993e-04 - accuracy: 1.0000
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.4765e-04 - accuracy: 1.0000
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.4453e-04 - accuracy: 1.0000
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 6.0582e-04 - accuracy: 1.0000
# Epoch 129/200
# 8/8 [==============================] - 0s 3ms/step - loss: 6.0140e-04 - accuracy: 1.0000
# Epoch 130/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.8615e-04 - accuracy: 1.0000
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.6371e-04 - accuracy: 1.0000
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.4514e-04 - accuracy: 1.0000
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4196e-04 - accuracy: 1.0000
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2968e-04 - accuracy: 1.0000
# Epoch 135/200
# 8/8 [==============================] - 0s 3ms/step - loss: 5.0429e-04 - accuracy: 1.0000
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0079e-04 - accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.8111e-04 - accuracy: 1.0000
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.6500e-04 - accuracy: 1.0000
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.6534e-04 - accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.8737e-04 - accuracy: 1.0000
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.8725e-04 - accuracy: 1.0000
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4933e-04 - accuracy: 1.0000
# Epoch 143/200
# 8/8 [==============================] - 0s 5ms/step - loss: 4.0834e-04 - accuracy: 1.0000
# Epoch 144/200
# 8/8 [==============================] - 0s 5ms/step - loss: 4.1183e-04 - accuracy: 1.0000
# Epoch 145/200
# 8/8 [==============================] - 0s 3ms/step - loss: 4.0012e-04 - accuracy: 1.0000
# Epoch 146/200
# 8/8 [==============================] - 0s 4ms/step - loss: 3.7972e-04 - accuracy: 1.0000
# Epoch 147/200
# 8/8 [==============================] - 0s 4ms/step - loss: 3.6826e-04 - accuracy: 1.0000
# Epoch 148/200
# 8/8 [==============================] - 0s 4ms/step - loss: 3.5768e-04 - accuracy: 1.0000
# Epoch 149/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4398e-04 - accuracy: 1.0000
# Epoch 150/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4102e-04 - accuracy: 1.0000
# Epoch 151/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4623e-04 - accuracy: 1.0000
# Epoch 152/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2634e-04 - accuracy: 1.0000
# Epoch 153/200
# 8/8 [==============================] - 0s 4ms/step - loss: 3.0880e-04 - accuracy: 1.0000
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0184e-04 - accuracy: 1.0000
# Epoch 155/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.9992e-04 - accuracy: 1.0000
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9116e-04 - accuracy: 1.0000
# Epoch 157/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8241e-04 - accuracy: 1.0000
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8572e-04 - accuracy: 1.0000
# Epoch 159/200
# 8/8 [==============================] - 0s 4ms/step - loss: 2.8171e-04 - accuracy: 1.0000
# Epoch 160/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6772e-04 - accuracy: 1.0000
# Epoch 161/200
# 8/8 [==============================] - 0s 4ms/step - loss: 3.1074e-04 - accuracy: 1.0000
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7220e-04 - accuracy: 1.0000
# Epoch 163/200
# 8/8 [==============================] - 0s 3ms/step - loss: 3.5348e-04 - accuracy: 1.0000
# Epoch 164/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5222e-04 - accuracy: 1.0000
# Epoch 165/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2822e-04 - accuracy: 1.0000
# Epoch 166/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2662e-04 - accuracy: 1.0000
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1633e-04 - accuracy: 1.0000
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0816e-04 - accuracy: 1.0000
# Epoch 169/200
# 8/8 [==============================] - 0s 5ms/step - loss: 2.0376e-04 - accuracy: 1.0000
# Epoch 170/200
# 8/8 [==============================] - 0s 5ms/step - loss: 1.9798e-04 - accuracy: 1.0000
# Epoch 171/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9258e-04 - accuracy: 1.0000
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8797e-04 - accuracy: 1.0000
# Epoch 173/200
# 8/8 [==============================] - 0s 5ms/step - loss: 1.8508e-04 - accuracy: 1.0000
# Epoch 174/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8165e-04 - accuracy: 1.0000
# Epoch 175/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7629e-04 - accuracy: 1.0000
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7253e-04 - accuracy: 1.0000
# Epoch 177/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7151e-04 - accuracy: 1.0000
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6740e-04 - accuracy: 1.0000
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6265e-04 - accuracy: 1.0000
# Epoch 180/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5657e-04 - accuracy: 1.0000
# Epoch 181/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5328e-04 - accuracy: 1.0000
# Epoch 182/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4969e-04 - accuracy: 1.0000
# Epoch 183/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4797e-04 - accuracy: 1.0000
# Epoch 184/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4426e-04 - accuracy: 1.0000
# Epoch 185/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4081e-04 - accuracy: 1.0000
# Epoch 186/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3854e-04 - accuracy: 1.0000
# Epoch 187/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3563e-04 - accuracy: 1.0000
# Epoch 188/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3311e-04 - accuracy: 1.0000
# Epoch 189/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.3055e-04 - accuracy: 1.0000
# Epoch 190/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2940e-04 - accuracy: 1.0000
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2655e-04 - accuracy: 1.0000
# Epoch 192/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2330e-04 - accuracy: 1.0000
# Epoch 193/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.2252e-04 - accuracy: 1.0000
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2054e-04 - accuracy: 1.0000
# Epoch 195/200
# 8/8 [==============================] - 0s 4ms/step - loss: 1.1711e-04 - accuracy: 1.0000
# Epoch 196/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1520e-04 - accuracy: 1.0000
# Epoch 197/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1352e-04 - accuracy: 1.0000
# Epoch 198/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1179e-04 - accuracy: 1.0000
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0939e-04 - accuracy: 1.0000
# Epoch 200/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0764e-04 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-3846859946b6> in <module>
#      13 history = model.fit(X_train_w, y_train_w, epochs=200)
#      14 predictions = model.predict(X_test_w)
# ---> 15 accuracy = accuracy_score(predictions,y_test_w)
#      16 print("Test Set Accuracy: {:.2%}".format(accuracy))
#
# /Volumes/Kieran_External_HD/Users/Kieran/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Volumes/Kieran_External_HD/Users/Kieran/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# /Volumes/Kieran_External_HD/Users/Kieran/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      91     if len(y_type) > 1:
#      92         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 93                          "and {1} targets".format(type_true, type_pred))
#      94
#      95     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of continuous-multioutput and multiclass targets

# %% [markdown]
# ### Random Forest - Spectral - w/SMOTE

# %%
# todo: I think we need to re-import the data for this cell, if this is run multiple times then y_train_w gets overwritten
y_train_w = pd.read_csv('../data/y_train_w.csv',index_col = 0)

#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_w['ensemble'].value_counts()
X_train_w = X_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
y_train_w = y_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]

# Fit and apply the transform
X_SMOTE_w, y_SMOTE_w = SMOTE(random_state=101).fit_resample(X_train_w, y_train_w)

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_w, y_SMOTE_w)
predictions = rf.predict(X_test_w)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Test Set Accuracy: 75.76%

# %% [markdown]
# ### SVM - Spectral - w/Hyperparameter Tuning + PCA + SMOTE

# %%
#Drop any ensemble types with counts below 6
counts = y_train_w['ensemble'].value_counts()
X_train_w_smote = X_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]
y_train_w_smote = y_train_w[~y_train_w['ensemble'].isin(counts[counts < 6].index)]

# fit and apply the transform
X_SMOTE, y_SMOTE = SMOTE().fit_resample(X_train_w_smote, y_train_w_smote.values.ravel())

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_SMOTE)
train_pca_w_smote = pca.transform(X_SMOTE)
X_test_w_pca = pca.transform(X_test_w)


from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid , cv=5)
  
# fitting the model for grid search
grid.fit(train_pca_w_smote, y_SMOTE)

print(grid.best_params_)

#Create SVM model with best hyperparameters, PCA and SMOTE

svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)
predictions = svm.predict(X_test_w_pca)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# {'C': 0.012742749857031334, 'gamma': 0.001, 'kernel': 'linear'}
# Test Set Accuracy: 78.79%

# %% [markdown]
# ### Random Forest - Midi - w/SMOTE

# %%
# todo: I think we need to re-import the data for this cell, if this is run multiple times then y_train_w gets overwritten
y_train_m = pd.read_csv('../data/y_train_m.csv',index_col = 0)

#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_m['ensemble'].value_counts()
X_train_m = X_train_m[~y_train_m['ensemble'].isin(counts[counts < 6].index)]
y_train_m = y_train_m[~y_train_m['ensemble'].isin(counts[counts < 6].index)]

# Fit and apply the transform
X_SMOTE_m, y_SMOTE_m = SMOTE(random_state=101).fit_resample(X_train_m, y_train_m)

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_m, y_SMOTE_m)
predictions = rf.predict(X_test_m)
accuracy = accuracy_score(predictions,y_test_m)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Test Set Accuracy: 83.33%

# %% [markdown]
# ### Random Forest - Combined - w/SMOTE

# %%
# todo: I think we need to re-import the data for this cell, if this is run multiple times then y_train_w gets overwritten
y_train_c = pd.read_csv('../data/y_train_c.csv',index_col = 0)

#Drop any ensemble types with counts below 6. This because Expected n_neighbors <= n_samples,  
#but n_samples = 3, n_neighbors = 6
counts = y_train_c['ensemble'].value_counts()
X_train_c = X_train_c[~y_train_c['ensemble'].isin(counts[counts < 6].index)]
y_train_c = y_train_c[~y_train_c['ensemble'].isin(counts[counts < 6].index)]

X_SMOTE_c, y_SMOTE_c = SMOTE(random_state=101).fit_resample(X_train_c, y_train_c)

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=1)
rf.fit(X_SMOTE_c, y_SMOTE_c)
predictions = rf.predict(X_test_c)
accuracy = accuracy_score(predictions,y_test_c)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Test Set Accuracy: 80.30%

# %% [markdown]
# ### SVM - Spectral - w/Hyperparameter Tuning + PCA + SMOTE + StandardScaler

# %%
#### Standard Scaler Application

#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_SMOTE)
train_pca_w_smote = pca.transform(X_SMOTE)
X_test_w_pca = pca.transform(X_test_w)


#Create SVM model with best hyperparameters, PCA and SMOTE and StandardScaler

svm = make_pipeline(StandardScaler() ,SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w_smote, y_SMOTE)


predictions = svm.predict(X_test_w_pca)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Test Set Accuracy: 74.24%

# %% [markdown]
# ### SVM - Spectral - w/Hyperparameter Tuning

# %%
#Find best hyperparameters
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),                     
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid, cv=5)
  
# fitting the model for grid search
grid.fit(X_train_w, y_train_w.values.ravel())

print(grid.best_params_)


#Create Model with best hyperparameters

svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(X_train_w, y_train_w.values.ravel())
predictions = svm.predict(X_test_w)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# {'C': 0.0018329807108324356, 'gamma': 0.001, 'kernel': 'linear'}
# Test Set Accuracy: 77.27%

# %% [markdown]
# ### SVM - Spectral - W/Hyperparameter Tuning + PCA

# %%
#Perform PCA with 15 components
pca=PCA(n_components = 15)
pca.fit(X_train_w)
train_pca_w = pca.transform(X_train_w)
X_test_w_pca = pca.transform(X_test_w)

from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': np.logspace(-4, 4, 20), 
              'gamma': np.logspace(-3, 2, 6),
              'kernel': ['linear','rbf','poly']} 
  
grid = GridSearchCV(SVC(), param_grid , cv=5)
  
# fitting the model for grid search
grid.fit(train_pca_w, y_train_w.values.ravel())

print(grid.best_params_)

#Create Model with best hyperparameters and PCA
svm = make_pipeline(SVC(kernel=grid.best_params_['kernel'], C = grid.best_params_['C'] , gamma=grid.best_params_['gamma']))
svm.fit(train_pca_w, y_train_w.values.ravel())
predictions = svm.predict(X_test_w_pca)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# {'C': 0.0018329807108324356, 'gamma': 0.001, 'kernel': 'linear'}
# Test Set Accuracy: 74.24%

# %% [markdown]
# ### Logistic Regression - Spectral - Baseline

# %%
#Create Baseline Logistic Model
lr = LogisticRegression(C = 0.5, solver='liblinear', multi_class='auto')
lr.fit(np.array(X_train_w), np.array(y_train_w))
predictions = lr.predict(X_test_w)
accuracy = accuracy_score(predictions,y_test_w)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Test Set Accuracy: 78.79%

# %% [markdown]
# ### Random Forest - Midi - Baseline

# %%
rf = RandomForestClassifier()
rf.fit(X_train_m, y_train_m)
predictions = rf.predict(X_test_m)
accuracy = accuracy_score(predictions,y_test_m)
print("Test Set Accuracy: {:.2%}".format(accuracy))
# Out:
# Test Set Accuracy: 83.33%

# %% [markdown]
# ## Final Test Results
#
# | Model               | Feature Set | Model Variant                                            | Mean CV Score | Test Score |
# |---------------------|-------------|----------------------------------------------------------|---------------|------------|
# | Neural Network      | Spectral    | Baseline (ADAM, 5 Hidden Layers)                         | 100%          | ?          |
# | Random Forest       | Spectral    | w/SMOTE                                                  | 99.56%        | 75.76%     |
# | SVM                 | Spectral    | w/Hyperparameter   Tuning + PCA + SMOTE                  | 99.38%        | 78.79%     |
# | Random Forest       | Midi        | w/SMOTE                                                  | 99.34%        | 83.33%     |
# | Random Forest       | Combined    | w/SMOTE                                                  | 99.29%        | 80.30%     |
# | SVM                 | Spectral    | w/Hyperparameter   Tuning + PCA + SMOTE + StandardScaler | 97.24%        | 74.24%     |
# | SVM                 | Spectral    | w/Hyperparameter   Tuning                                | 91.35%        | 77.27%     |
# | SVM                 | Spectral    | w/Hyperparamater   Tuning + PCA                          | 90.47%        | 74.24%     |
# | Logistic Regression | Spectral    | Baseline                                                 | 89.75%        | 78.79%     |
# | Random Forest       | Midi        | Baseline                                                 | 89.75%        | 83.33%     |
